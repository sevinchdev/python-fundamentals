# %%
fruit = "apple banana"

# %%
fruit.lower()
# Out:
# 'apple banana'

# %%
fruit.upper()
# Out:
# 'APPLE BANANA'

# %%
fruit.capitalize()
# Out:
# 'Apple banana'

# %%
fruit.title()
# Out:
# 'Apple Banana'

# %%
fruit.endswith("b")
# Out:
# False

# %%
fruit.startswith("a")
# Out:
# True

# %%
print("-  "*10)
# Out:
# -  -  -  -  -  -  -  -  -  -

# %%
word = "  Hello, World!  "

# %%
print(word)
# Out:
#   Hello, World!

# %%
word.strip()
# Out:
# 'Hello, World!'

# %%
fruits = "apple banana cherry"

# %%
fruits.split(" ")
# Out:
# ['apple', 'banana', 'cherry']

# %%
name = "Sevinch, Akbar"
name.split(",")
# Out:
# ['Sevinch', ' Akbar']

# %%
file_name = "numeric.py"

# %%
file_name.split(".")[0]
# Out:
# 'numeric'

# %%
file_name.split(".")[1]
# Out:
# 'py'

# %%
directory = r"D:\Python\bi-and-ai-talents\lesson-2\homework"

# %%
type(directory)
# Out:
# str

# %%
directory
# Out:
# 'D:\\Python\\bi-and-ai-talents\\lesson-2\\homework'
